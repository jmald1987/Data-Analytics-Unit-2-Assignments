# %% [markdown]
# <a href="https://colab.research.google.com/github/niteen11/lagcc_data_analytics_micro_credential/blob/master/Unit%202%20-%20Python%20Fundamentals/Assignments/Unit2_Dictionary_Assignment_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Intrdouction to Python - Dictionary - Assignment #5

# %% [markdown]
# ## 1.	Create a simple dictionary that stores 2 variables, for example: first and last name.

# %%
dict={'firstName':'Johnny','lastName':'Maldonado'}

# %% [markdown]
# ## 2.	Print out those variables stored in your previous dictionary.

# %%
dict
# Out:
# {'firstName': 'Johnny', 'lastName': 'Maldonado'}

# %% [markdown]
# ## 3.	Add a message to those variables on printing: for example: “Hello, firstname lastname!”

# %%
print("Hello,",dict['firstName'],dict['lastName']+"!")
# Out:
# Hello, Johnny Maldonado!

# %% [markdown]
# ## 4.	Create a dictionary that holds 2 key: value pairs:
#
# a.	Look through your dictionary and print each pair,

# %%
print(dict['firstName'],dict['lastName'])
# Out:
# Johnny Maldonado

# %%
dict2={'fruit':'Apple','type':'Juice'}
print(dict2['fruit'],dict2['type'])
# Out:
# Apple Juice

# %%
dict3={'fruit':'Apple','type':'Juice'}
